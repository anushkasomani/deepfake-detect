# %% [markdown]
# # Deepfake Audio Detection
#
#  Used the [Fake-or-Real for-norm dataset](https://www.kaggle.com/datasets/mohammedabdeldayem/the-fake-or-real-dataset).

# %%
# !pip install -q -r requirements.txt

# %%
# 500 files per class (~20-40 min). Increase or remove --max_samples for more data.
# !python train.py --kaggle --output_dir /kaggle/working/artifacts --max_samples 500

# %%
import json
from pathlib import Path

out = Path('/kaggle/working/artifacts')
print(json.dumps(json.loads((out / 'metrics.json').read_text()), indent=2))
print('Model (MB):', round((out / 'model.joblib').stat().st_size / 1e6, 2))
